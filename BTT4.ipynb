# %% [markdown]
# ### W4A1
# Viết chương trình Python sử dụng một trong 2 loại vòng lặp for hoặc while để
# tính tống các số nguyên từ 1 đến n. (n <= 1000)

# %%
a=int(input())
tong=0
for i in range(a+1):
    tong+=1
    if tong==(a+1):
        break
    print(tong)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6

# %%
i=0
while i<5:
    print(i)
    i+=1
# Out:
# 0
# 1
# 2
# 3
# 4

# %% [markdown]
# ### W4A2
# [PrimeNumber]
# VIết chương trình nhập vào một số tới khi được một số n

# %%
import math
a=int(input())
while a<=0:
    a=int(input())
for i in range(math.isqrt(a)+1):
    if a%i!=0:
        print("Là số nguyên tố")
    if a%i==0:
        print("Không là số nguyên tố")
# Out:
# 1

# %% [markdown]
# ### W4A3
# [Factorial]
# Viết chương trình tính giai thừa của một số nguyên n cho trước (n!=1×2×…×n)
# với 0 < n < 100.

# %%
n=int(input())
b=1
for i in range(1,n+1):
    if n<100:
        b=b*i
print(b)
# Out:
# 3628800

# %% [markdown]
# ### W4A4
# .[CountingDigits]
# Viết chương trình nhập vào một số nguyên n và in ra màn hình số chữ số (trừ dấu)
# của số đó. Không dùng kiểu dữ liệu string.

# %%
a=abs(int(input()))
c=0
while a>0:
    c+=1
    a=a//10
print(c)
# Out:
# 2
