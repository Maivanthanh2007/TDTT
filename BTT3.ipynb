# %% [markdown]
# ## for loop

# %%
for i in range (11,2):
    print (i)

# %%
a= float(input())
if (a%2==0):
    print("số chẵn bro")
else:
    print ("số lẻ blud ")
# Out:
# số chẵn bro

# %%
n=6 
while n>0:
    print(n)
    n -=2
# Out:
# 6
# 4
# 2

# %%
a,b = map(int,input().split())
# Phải nhớ map
if a<0 and b<0:
    print("Yes")
else:
    print("No")
# Out:
# Yes

# %%
a=input()
b=input()
if len(a)>len(b):
    print("True")
else:
    print("No")
# hàm này để so sánh độ dài chuỗi
# Out:
# True

# %%
a,b,c= map(int,input().split())
p= (a+b+c)/2
s= p*(p-a)*(p-b)*(p-c)
if a>0 and b>0 and c>0 and s>0:
    print ("là tam giác")
else:
    print ("ông chú nginh")
# Out:
# là tam giác

# %%
a=float(input())
if a >= 8.0:
    print ("Tày")
elif 8.0>a>=6.5:
    print ("Khá")
elif 6.5>a>=5.0:
    print ("Trung Bình")
else:
    print ("Yếu")
# Out:
# Tày
